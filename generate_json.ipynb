# %%
import pandas as pd
import matplotlib.pyplot as plt


# Load the Premier League table CSV
df = pd.read_csv('pl-tables-1993-2024.csv')

df
# Out:
#      season_end_year               team  position  played  won  drawn  lost  \
# 0               1993     Manchester Utd         1      42   24     12     6
# 1               1993        Aston Villa         2      42   21     11    10
# 2               1993       Norwich City         3      42   21      9    12
# 3               1993          Blackburn         4      42   20     11    11
# 4               1993                QPR         5      42   17     12    13
# ..               ...                ...       ...     ...  ...    ...   ...
# 641             2024          Brentford        16      38   10      9    19
# 642             2024  Nottingham Forest        17      38    9      9    20
# 643             2024         Luton Town        18      38    6      8    24
# 644             2024            Burnley        19      38    5      9    24
# 645             2024      Sheffield Utd        20      38    3      7    28
#
#      gf   ga  gd  points                                 notes
# 0    67   31  36      84  → Champions League via league finish
# 1    57   40  17      74          → UEFA Cup via league finish
# 2    61   65  -4      72        → UEFA Cup via league finish 1
# 3    68   46  22      71                                   NaN
# 4    63   55   8      63                                   NaN
# ..   ..  ...  ..     ...                                   ...
# 641  56   65  -9      39                                   NaN
# 642  49   67 -18      32                     4-point deduction
# 643  52   85 -33      26                             Relegated
# 644  41   78 -37      24                             Relegated
# 645  35  104 -69      16                             Relegated
#
# [646 rows x 12 columns]

# %%
# Basic info summary
info = df.info(buf=None)

# Descriptive statistics for numeric columns
desc = df.describe()
desc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season_end_year  646 non-null    int64
#  1   team             646 non-null    object
#  2   position         646 non-null    int64
#  3   played           646 non-null    int64
#  4   won              646 non-null    int64
#  5   drawn            646 non-null    int64
#  6   lost             646 non-null    int64
#  7   gf               646 non-null    int64
#  8   ga               646 non-null    int64
#  9   gd               646 non-null    int64
#  10  points           646 non-null    int64
#  11  notes            326 non-null    object
# dtypes: int64(10), object(2)
# memory usage: 60.7+ KB
#        season_end_year    position      played         won       drawn  \
# count       646.000000  646.000000  646.000000  646.000000  646.000000
# mean       2008.365325   10.602167   38.408669   14.283282    9.842105
# std           9.302311    5.840351    1.212411    5.741345    2.956505
# min        1993.000000    1.000000   38.000000    1.000000    2.000000
# 25%        2000.000000    6.000000   38.000000   10.000000    8.000000
# 50%        2008.000000   11.000000   38.000000   13.000000   10.000000
# 75%        2016.000000   16.000000   38.000000   18.000000   12.000000
# max        2024.000000   22.000000   42.000000   32.000000   18.000000
#
#              lost          gf          ga          gd      points
# count  646.000000  646.000000  646.000000  646.000000  646.000000
# mean    14.283282   51.577399   51.577399    0.000000   52.654799
# std      5.401573   15.195452   13.035291   24.952482   16.499190
# min      0.000000   20.000000   15.000000  -69.000000   11.000000
# 25%     10.250000   41.000000   43.000000  -17.000000   41.000000
# 50%     15.000000   48.000000   52.000000   -5.000000   50.000000
# 75%     18.000000   60.750000   59.750000   15.000000   63.000000
# max     29.000000  106.000000  104.000000   79.000000  100.000000

# %%
# How many unique clubs and seasons?
n_clubs = df['team'].nunique()
n_seasons = df['season_end_year'].nunique()

print(f"Unique clubs: {n_clubs}")
print(f"Seasons (1993/94 to 2023/24): {n_seasons}")
# Out:
# Unique clubs: 51
# Seasons (1993/94 to 2023/24): 32

# %%
import pandas as pd, json, os, statistics

# ---- Filter the decade window ----
decade = (df[df["season_end_year"].between(2015, 2024)]
            .sort_values(["team", "season_end_year"]))

records = []
for club, grp in decade.groupby("team"):
    season_rows = []
    for _, row in grp.iterrows():
        season_rows.append({
            "year"    : int(row["season_end_year"]),
            "points"  : int(row["points"]),
            "position": int(row["position"]),
            "gd"      : int(row["gd"]),
            "won"     : int(row["won"]),
            "drawn"   : int(row["drawn"]),
            "lost"    : int(row["lost"]),
            "gf"      : int(row["gf"]),
            "ga"      : int(row["ga"]),
            "notes"   : row["notes"] if pd.notna(row["notes"]) else ""
        })

    pts = [s["points"] for s in season_rows]          # club‑level quick stats
    records.append({
        "team"        : club,
        "values"      : season_rows,
        "total_pts"   : sum(pts),
        "avg_pts"     : round(statistics.mean(pts), 2),
        "best_pts"    : max(pts),
        "seasons_played": len(season_rows)
    })

# ---- Write JSON to disk ----
os.makedirs("data", exist_ok=True)
with open("data/teams_points_2015-24.json", "w", encoding="utf-8") as f:
    json.dump(records, f, indent=2)

print(f"✓ JSON saved to data/teams_points_2015-24.json — {len(records)} clubs "
      f"({decade['team'].nunique()} with ≥1 season)")
# Out:
# ✓ JSON saved to data/teams_points_2015-24.json — 34 clubs (34 with ≥1 season)

# %%
df[df['position'] == 1].sort_values('season_end_year')
# Out:
#      season_end_year             team  position  played  won  drawn  lost  \
# 0               1993   Manchester Utd         1      42   24     12     6
# 22              1994   Manchester Utd         1      42   27     11     4
# 44              1995        Blackburn         1      42   27      8     7
# 66              1996   Manchester Utd         1      38   25      7     6
# 86              1997   Manchester Utd         1      38   21     12     5
# 106             1998          Arsenal         1      38   23      9     6
# 126             1999   Manchester Utd         1      38   22     13     3
# 146             2000   Manchester Utd         1      38   28      7     3
# 166             2001   Manchester Utd         1      38   24      8     6
# 186             2002          Arsenal         1      38   26      9     3
# 206             2003   Manchester Utd         1      38   25      8     5
# 226             2004          Arsenal         1      38   26     12     0
# 246             2005          Chelsea         1      38   29      8     1
# 266             2006          Chelsea         1      38   29      4     5
# 286             2007   Manchester Utd         1      38   28      5     5
# 306             2008   Manchester Utd         1      38   27      6     5
# 326             2009   Manchester Utd         1      38   28      6     4
# 346             2010          Chelsea         1      38   27      5     6
# 366             2011   Manchester Utd         1      38   23     11     4
# 386             2012  Manchester City         1      38   28      5     5
# 406             2013   Manchester Utd         1      38   28      5     5
# 426             2014  Manchester City         1      38   27      5     6
# 446             2015          Chelsea         1      38   26      9     3
# 466             2016   Leicester City         1      38   23     12     3
# 486             2017          Chelsea         1      38   30      3     5
# 506             2018  Manchester City         1      38   32      4     2
# 526             2019  Manchester City         1      38   32      2     4
# 546             2020        Liverpool         1      38   32      3     3
# 566             2021  Manchester City         1      38   27      5     6
# 586             2022  Manchester City         1      38   29      6     3
# 606             2023  Manchester City         1      38   28      5     5
# 626             2024  Manchester City         1      38   28      7     3
#
#       gf  ga  gd  points                                        notes
# 0     67  31  36      84         → Champions League via league finish
# 22    80  38  42      92         → Champions League via league finish
# 44    80  39  41      89         → Champions League via league finish
# 66    73  35  38      82         → Champions League via league finish
# 86    76  44  32      75         → Champions League via league finish
# 106   68  33  35      78         → Champions League via league finish
# 126   80  37  43      79         → Champions League via league finish
# 146   97  45  52      91         → Champions League via league finish
# 166   79  31  48      80         → Champions League via league finish
# 186   79  36  43      87         → Champions League via league finish
# 206   74  34  40      83         → Champions League via league finish
# 226   73  26  47      90         → Champions League via league finish
# 246   72  15  57      95         → Champions League via league finish
# 266   72  22  50      91         → Champions League via league finish
# 286   83  27  56      89         → Champions League via league finish
# 306   80  22  58      87  → Champions League via Champions League win
# 326   68  24  44      90         → Champions League via league finish
# 346  103  32  71      86         → Champions League via league finish
# 366   78  37  41      80         → Champions League via league finish
# 386   93  29  64      89         → Champions League via league finish
# 406   86  43  43      89         → Champions League via league finish
# 426  102  37  65      86         → Champions League via league finish
# 446   73  32  41      87         → Champions League via league finish
# 466   68  36  32      81         → Champions League via league finish
# 486   85  33  52      93         → Champions League via league finish
# 506  106  27  79     100         → Champions League via league finish
# 526   95  23  72      98         → Champions League via league finish
# 546   85  33  52      99         → Champions League via league finish
# 566   83  32  51      86         → Champions League via league finish
# 586   99  26  73      93         → Champions League via league finish
# 606   94  33  61      89         → Champions League via league finish
# 626   96  34  62      91         → Champions League via league finish
